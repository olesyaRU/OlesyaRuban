# %% [markdown]
# # Программирование на Python
# ## Семинар 5. Функции
# #### Задача 1 (жизненная)
# Предположим, что вам необходимо разместить некоторую таблицу на веб-странице. Таблица имеется у вас в формате `csv`. Для размещения на странице необходимо сгенерировать `html`-код, который бы размечал данную таблицу. Вручную вы, конечно, делать это не будете. Кроме того, подобная задача может встретиться вам снова. Поэтому напишите функцию, которая будет принимать на вход путь к `csv`-файлу и сохранять его копию в `html`-формате в новом файле.
#
# Для тренировки воспользуйтесь файлом `cortisol.csv`.
#
# **Алгоритм решения**
# 1. Выяснить значение непонятных терминов: csv, html (а конкретно как там делать таблицы);
# 2. Выяснить, как работать с файлами;
# 3. Разбить задачу на логически связанные и в то же время обособленные друг от друга подзадачи.
#
# **Как выяснять**
# 1. Загуглить (лучше на английском);
# 2. Если тратите на поиск больше 5-10 минут либо на понимание больше двух часов - спросите у более опытных коллег;
# 3. Если просите информацию у коллеги, узнайте, где он ее добыл (и если получится - попросите показать как он бы искал ее самостоятельно);
# 4. Если в процессе гугления вам встречаются еще непонятные термины, но к вашей теме они не относятся, НЕ ГУГЛИТЕ ИХ, потеряете время;
#
# **План**
# 1. Прочитать информацию из файла;
# 2. Преобразовать в HTML-формат;
# 3. Записать в другой файл;
# 4. Оформить все это в виде функции.

# %% [markdown]
# <p>Какой-то текст</p>
#
# <b>Жирный текст</b>
#
# <table>
#     <thead>
#         <tr>
#             <th>Заголовок 1</th>
#             <th>Заголовок 2</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Ячейка 1.1</td>
#             <td>Ячейка 1.2</th>
#         </tr>
#         <tr>
#             <td>Ячейка 2.1</td>
#             <td>Ячейка 2.2</td>
#         </tr>
#     </tbody>
# </table>

# %%
# наш код здесь

# %% [markdown]
# #### Задача 2
# Напишите функцию, которая будет переводить `int` в `str` без использования функции `str()`.

# %%
# наш код здесь

# %% [markdown]
# #### Задача 3
# Решите прошлую задачу рекурсивно.

# %%
# наш код здесь
